# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df= pd.read_csv("ibm.csv")

# %%
lan=["c","c++","java"]
stu =[25,45,30]
plt.pie(stu,labels=lan,autopct= "%.3f%%")
plt.show()

# %%
df.head(3)
# Out:
#   Domain Code                                             Domain  Survey Code  \
# 0          HS  Indicators from Household Surveys (gender, are...   1620002001
# 1          HS  Indicators from Household Surveys (gender, are...   1620002001
# 2          HS  Indicators from Household Surveys (gender, are...   1620002001
#
#                    Survey  Breakdown Variable Code Breakdown Variable  \
# 0  Bangladesh - 2000-2001                    20008      Country-level
# 1  Bangladesh - 2000-2001                    20008      Country-level
# 2  Bangladesh - 2000-2001                    20008      Country-level
#
#    Breadown by Sex of the Household Head Code  \
# 0                                       20002
# 1                                       20002
# 2                                       20002
#
#   Breadown by Sex of the Household Head  Indicator Code  \
# 0                 Male-headed household            6061
# 1                 Male-headed household            6061
# ...

# %%
lan=df['Indicator']
stu=df['Value']
plt.pie(stu,labels=lan,autopct= "%.3f%%")
plt.show()

# %%
lan=df['Indicator'].unique()
stu=df['Value'].groupby(df['Indicator']).sum()
plt.pie(stu,labels=lan,autopct= "%.3f%%")
plt.show()
